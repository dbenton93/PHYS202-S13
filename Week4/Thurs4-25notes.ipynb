# %%
from Electrostatics import *
from mpl_toolkits.mplot3d import Axes3D

# %%
x,y = meshgrid(arange(-3.,3.,.037),arange(-3.,3.,.037))
Vdipole = dipolePotential(x,y,3e-9,.01)
Vpoint = pointPotential(x,y,-2e-9,0,-.005)
Vtotal = Vdipole + Vpoint


fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x,y, Vtotal, rstride=1, cstride=1, lw=0, cmap=cm.PRGn)
cb = fig.colorbar(p, shrink=.5)

# %% [markdown]
# Using Boolean Masks to find data

# %%
theta = arange(0.,2*pi,pi/100)
plot(theta,sin(theta))
show()

# %%
mask = (sin(theta)>-0.5) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
show()

# %%
y = sin(theta[mask])
jj = (y == max(y))
ii = (y == min(y))
y[jj] = NaN
y[ii]= NaN

# %%
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)
show()

# %% [markdown]
# INTERPOLATION

# %%
theta=arange(0.,2*pi+0.1,pi/10)
mask = (theta==0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newtheta = 0.5; newsin = 0

# %%
from scipy.interpolate import interp1d
#help(interp1d)
sininterp = interp1d(theta,sin(theta))
newsin = sininterp(newtheta)
print newsin
# Out:
# 0.473922198704

# %%
thetanew = arange(0.,2*pi,pi/30)
sinnew = interp1d(theta,sin(theta))(thetanew)
plot(theta,sin(theta), thetanew, sinnew, 'r.')
show()
