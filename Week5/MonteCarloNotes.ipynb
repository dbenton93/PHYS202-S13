# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$X^{1/2} + \sin(x)$',fontsize=20)
xlabel(r'$x$',fontsize = 20)
xlim(0.,15.)
# Out:
# (0.0, 15.0)

# %%
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x > xmin),(xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

# %%
N = 1000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:200],samples_y[1:200],'.')
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)
# Out:
# 494878

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:],samples_y[1:],'.')
plot(samples_x[newmask[:]],samples_y[newmask[:]],'.', color='r')
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size

# %%
print I
# Out:
# 26.5140656116

# %%
Iana = lambda x:(2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
error = 100*(Iexact-I)/Iexact

# %%
print Iexact
# Out:
# 26.5172145362

# %%
print I
# Out:
# 26.5140656116

# %%
print error
# Out:
# 0.0118750203687

# %% [markdown]
# Ex2

# %%
N = 10000
a = 1.7
b = 12.4
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);
x = arange(0.,15.,0.001)
print f(x)
# Out:
# [ 0.          0.03262278  0.04672136 ...,  4.52516     4.52453105
#   4.52390145]

# %%
plot (x,f(x))
myplot = plot(x,f(x),lw=3)
ylabel(r'$X^{1/2} + \sin(x)$',fontsize=20)
xlabel(r'$x$',fontsize = 20)
xlim(0.,15.)
I_n = ((b-a)*(sum((f(samples_x)))/N))
avg = (sum((f(samples_x)))/N)
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x > xmin),(xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

plot([xmin, xmax], [avg, avg], color='k',lw=3)
print I_n
# Out:
# 26.5320942205

# %%
error = 100*(Iexact-I_n)/Iexact
print error
# Out:
# -0.0561133004964

# %% [markdown]
# Gives a smaller error, for n=10000
