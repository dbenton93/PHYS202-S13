# %%
import math
import numpy as np

# %%
x = arange(-3,3,.01)
C = 1
a = 1
fx = C*e**(-a*abs(x))
plot(x,fx)
xlabel('units of 1/$a$',fontsize=16)
ylabel('units of $C$',fontsize=16)
title('$Ce^{-a|x|}$', fontsize=24)

# %% [markdown]
# 1a)

# %% [markdown]
# 1c)

# %%
k = arange(-3,3,.001)
ak = a*C/(pi*(a**2+k**2))
plot(k,ak)
title('Fourier Transform of $Ce^{-a|x|}$ vs. k',fontsize=24)
xlabel('k in units of sqrt(a*(c-pi*a)/pi)')
ylabel('A(k) in units of C')
